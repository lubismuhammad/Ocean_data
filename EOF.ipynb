# %%
# %load_ext ferretmagic

# %%
# %%ferret
# ca da/all
# use batnas_new.nc
# use HASIL_EOF_V_100.nc
#
# sh da
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> ./batnas_new.nc
#  name     title                             I         J         K         L
#  CRS      CRS definition                   ...       ...       ...       ...
#  TOPO     GDAL Band Number 1               1:36000   1:15000   ...       ...
#
#     2> ./HASIL_EOF_V_100.nc  (default)
#  name     title                             I         J         K         L
#  V_SPACE  EOFSVD_SPACE(V_AN)               1:73      1:97      1:1       1:7081
#  V_STAT   EOFSVD_STAT(V_AN)                1:7081    1:3       1:1       ...
#  V_TFUNC  EOFSVD_TFUNC(V_AN)               1:7081    ...       1:1       1:4017
#        (T=31-DEC-2012 12:00:31-DEC-2023 12:00)
#
# </pre>

# %%
# %%ferret
# set win/as=1.3
# fill/nolab/pal=darkred_blue/lev=(-inf)(-0.15,0.15,0.01)(inf) v_space[l=2];
# contour/ov/lev=0.03d/nolab;
# contour/ov/col=1/lev=(0,4000,3000)/nolab topo[x=124:132,y=-5:4,d=1];
# fill/ov/lev=(0,10000,10000)/pal=gray/nolab topo[x=124:132,y=-5:4,d=1];
# frame/file=eof2_v_100m.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# set win/as=0.3
# plot/nolab/vgrat=dash/vlim=-3.7:3.7:0.5/thick=2 v_tfunc[i=1]
# frame/file=ts_eof1_v_100m.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# list v_stat[i=1:5,j=2]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : EOFSVD_STAT(V_AN)
#              FILENAME : HASIL_EOF_V_100.nc
#              SUBSET   : 5 points (X)
#              Y        : 2
#              DEPTH (m): 100
#              2
#              2
#  1   / 1:  24.99
#  2   / 2:  17.74
#  3   / 3:   6.72
#  4   / 4:   5.46
#  5   / 5:   3.80
# </pre>

# %%
# %%ferret
# ca da/all
# use batnas_new.nc
# use HASIL_EOF_SSH.nc
#
# sh da
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> ./batnas_new.nc
#  name     title                             I         J         K         L
#  CRS      CRS definition                   ...       ...       ...       ...
#  TOPO     GDAL Band Number 1               1:36000   1:15000   ...       ...
#
#     2> ./HASIL_EOF_SSH.nc  (default)
#  name     title                             I         J         K         L
#  SSH_SPACE
#           EOFSVD_SPACE(SSH_AN)             1:73      1:97      ...       1:7081
#  SSH_STAT EOFSVD_STAT(SSH_AN)              1:7081    1:3       ...       ...
#  SSH_TFUNC
#           EOFSVD_TFUNC(SSH_AN)             1:7081    ...       ...       1:4017
#        (T=31-DEC-2012 12:00:31-DEC-2023 12:00)
#
# </pre>

# %%
# %%ferret
# set win/as=1.3
# fill/nolab/lev=(-inf)(-0.09,-0.055,0.001)(inf)/pal=darkred_blue ssh_space[l=1];
# contour/ov/lev=0.005d/nolab;
# contour/ov/col=1/lev=(0,4000,3000)/nolab topo[x=124:132,y=-5:4,d=1];
# fill/ov/lev=(0,10000,10000)/pal=gray/nolab topo[x=124:132,y=-5:4,d=1];
# frame/file=eof1_ssh.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# set win/as=0.3
# plot/nolab/vgrat=dash/thick=3/vlim=-3:3:0.5 ssh_tfunc[i=1]
# frame/file=ts_eof1_ssh_.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# list ssh_stat[i=1:5,j=2]
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">             VARIABLE : EOFSVD_STAT(SSH_AN)
#              FILENAME : HASIL_EOF_SSH.nc
#              SUBSET   : 5 points (X)
#              Y        : 2
#              2
#              2
#  1   / 1:  88.06
#  2   / 2:   9.69
#  3   / 3:   0.78
#  4   / 4:   0.32
#  5   / 5:   0.16
# </pre>

# %%
# %%ferret
# CA DA/ALL
# CA VAR/ALL
# set me/size=20000
# USE salt_gabung_100.nc
# let salt_an=saltz-saltz[l=@ave]
# let salt_space=EOFSVD_SPACE(salt_an)
# let salt_stat = EOFSVD_STAT(salt_an)
# let salt_tfunc = EOFSVD_TFUNC(salt_an)
# save/file=HASIL_EOF_SALTZ_100.nc salt_space,salt_stat,salt_tfunc
# Out:
#  LISTing to file HASIL_EOF_SALTZ_100.nc

# %%
# %%ferret
# ca da/all
# use batnas_new.nc
# use HASIL_EOF_SALTZ_100.nc
# sh da
# Out:
# <pre style="background-color:#ECF6CE; border-radius: 4px 4px 4px 4px; font-size: smaller">     currently SET data sets:
#     1> ./batnas_new.nc
#  name     title                             I         J         K         L
#  CRS      CRS definition                   ...       ...       ...       ...
#  TOPO     GDAL Band Number 1               1:36000   1:15000   ...       ...
#
#     2> ./HASIL_EOF_SALTZ_100.nc  (default)
#  name     title                             I         J         K         L
#  SALT_SPACE
#           EOFSVD_SPACE(SALT_AN)            1:73      1:97      1:1       1:7081
#  SALT_STAT
#           EOFSVD_STAT(SALT_AN)             1:7081    1:3       1:1       ...
#  SALT_TFUNC
#           EOFSVD_TFUNC(SALT_AN)            1:7081    ...       1:1       1:4017
#        (T=31-DEC-2012 12:00:31-DEC-2023 12:00)
#
# </pre>

# %%
# %%ferret
# ca var/all
# set win/as=1.3
# fill/nolab/pal=darkred_blue/lev=(-inf)(-0.13,0.13,0.005)(inf) salt_space[l=1];
# contour/ov/lev=0.02d/nolab;
# contour/ov/col=1/lev=(0,4000,3000)/nolab topo[x=124:132,y=-5:4,d=1];
# fill/ov/lev=(0,10000,10000)/pal=gray/nolab topo[x=124:132,y=-5:4,d=1];
# frame/file=eof1_salt.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# ca var/all
# set win/as=1.3
# fill/nolab/pal=darkred_blue/lev=(-inf)(-0.13,0.13,0.005)(inf) salt_space[l=2];
# contour/ov/lev=0.02d/nolab;
# contour/ov/col=1/lev=(0,4000,3000)/nolab topo[x=124:132,y=-5:4,d=1];
# fill/ov/lev=(0,10000,10000)/pal=gray/nolab topo[x=124:132,y=-5:4,d=1];
# frame/file=eof2_salt.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# ca var/all
# set win/as=1.3
# fill/nolab/pal=darkred_blue/lev=(-inf)(-0.13,0.13,0.005)(inf) salt_space[l=3];
# contour/ov/lev=0.02d/nolab;
# contour/ov/col=1/lev=(0,4000,3000)/nolab topo[x=124:132,y=-5:4,d=1];
# fill/ov/lev=(0,10000,10000)/pal=gray/nolab topo[x=124:132,y=-5:4,d=1];
# !frame/file=eof1_ssh.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# set win/as=0.3
# plot/nolab/vgrat=dash/thick=3/vlim=-3:3:0.5 salt_tfunc[i=1]
# frame/file=ts_eof1_salt_.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>

# %%
# %%ferret
# set win/as=0.3
# plot/nolab/vgrat=dash/thick=3/vlim=-3:3:0.5 salt_tfunc[i=2]
# frame/file=ts_eof2_salt_.pdf/ypixels=3000
# Out:
# <div class="myoutput"><img src="data:image/png;base64,..."/></div>
